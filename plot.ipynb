# %%
# %run data_2012.ipynb
# %run data_2013.ipynb
# %run data_2014.ipynb
# %run data_2015.ipynb

# %%
data12.head()
#plottable_dates= pd.to_datetime(data12.index)
periods = data12.index.to_native_types?

# %%
data12.index = data12.index.to_series().astype(str)
xTicks = data12.index

#plt.xticks(x, xTicks)
xTicks.astype(list)
# Out:
# Index(['2012-01', '2012-02', '2012-03', '2012-04', '2012-05', '2012-06',
#        '2012-07', '2012-08', '2012-09', '2012-10', '2012-11', '2012-12'],
#       dtype='object', name='DateMonth')

# %%
#plt.plot_date(data12["NO2"],xTicks , '-r')
plotter = ['2012-01', '2012-02', '2012-03', '2012-04', '2012-05', '2012-06','2012-07', '2012-08', '2012-09', '2012-10', '2012-11', '2012-12']
x = np.arange(0,len(data12["NO2"]),1)
fig, ax = plt.subplots(1,1)
ax.plot(x, data12["NO2"])
ax.set_xticks(x)
plt.xticks(rotation=45)
plt.subplots_adjust(bottom=0.2)

ax.set_xticklabels(plotter)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
