# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
dateparse = lambda x: pd.datetime.strptime(x, '%d/%m/%Y')

data12 = pd.read_csv("cpcb_dly_aq_delhi-2012.csv", parse_dates=['Sampling Date'], date_parser=dateparse).drop("Location of Monitoring Station", axis=1).sort_values("Sampling Date")

# %%
data12["DateMonth"] = data12["Sampling Date"].dt.to_period("M")
type(data12["DateMonth"][0])
# Out:
# pandas._libs.period.Period

# %%
data12 = data12.groupby("DateMonth").mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-5740b60c59d2> in <module>()
# ----> 1 data12 = data12.groupby("DateMonth").mean()
#
# C:\Users\mittr\Anaconda3\lib\site-packages\pandas\core\groupby.py in __getattr__(self, attr)
#     546             return self[attr]
#     547         if hasattr(self.obj, attr):
# --> 548             return self._make_wrapper(attr)
#     549
#     550         raise AttributeError("%r object has no attribute %r" %
#
# C:\Users\mittr\Anaconda3\lib\site-packages\pandas\core\groupby.py in _make_wrapper(self, name)
#     560                    "using the 'apply' method".format(kind, name,
#     561                                                      type(self).__name__))
# --> 562             raise AttributeError(msg)
#     563
#     564         # need to setup the selection
#
# AttributeError: Cannot access callable attribute 'groupby' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %%
data12.mean?

# %%
data12.head(2)
# Out:
#      Stn Code Sampling Date  State City/Town/Village/Area  \
# 200       345    2012-01-02  Delhi                  Delhi
# 8         144    2012-01-02  Delhi                  Delhi
# 201       345    2012-02-02  Delhi                  Delhi
# 209       345    2012-02-02  Delhi                  Delhi
# 96        146    2012-03-01  Delhi                  Delhi
# 10        144    2012-03-02  Delhi                  Delhi
# 97        146    2012-04-01  Delhi                  Delhi
# 217       345    2012-04-04  Delhi                  Delhi
# 218       345    2012-05-04  Delhi                  Delhi
# 26        144    2012-05-04  Delhi                  Delhi
# 50        144    2012-06-07  Delhi                  Delhi
# 162       146    2012-06-09  Delhi                  Delhi
# 192       345    2012-07-01  Delhi                  Delhi
# 0         144    2012-07-01  Delhi                  Delhi
# 193       345    2012-08-01  Delhi                  Delhi
# 1         144    2012-08-01  Delhi                  Delhi
# 106       146    2012-09-02  Delhi                  Delhi
# 205       345    2012-09-02  Delhi                  Delhi
# 99        146    2012-10-01  Delhi                  Delhi
# 27        144    2012-10-04  Delhi                  Delhi
# 100       146    2012-11-01  Delhi                  Delhi
# 28        144    2012-11-04  Delhi                  Delhi
# 101       146    2012-12-01  Delhi                  Delhi
# 147       146    2012-12-07  Delhi                  Delhi
#
#                                                 Agency  \
# 200  National Environmental Engineering Research In...
# 8    National Environmental Engineering Research In...
# 201  National Environmental Engineering Research In...
# 209  National Environmental Engineering Research In...
# 96   National Environmental Engineering Research In...
# 10   National Environmental Engineering Research In...
# 97   National Environmental Engineering Research In...
# 217  National Environmental Engineering Research In...
# 218  National Environmental Engineering Research In...
# 26   National Environmental Engineering Research In...
# 50   National Environmental Engineering Research In...
# 162  National Environmental Engineering Research In...
# 192  National Environmental Engineering Research In...
# 0    National Environmental Engineering Research In...
# 193  National Environmental Engineering Research In...
# 1    National Environmental Engineering Research In...
# 106  National Environmental Engineering Research In...
# 205  National Environmental Engineering Research In...
# 99   National Environmental Engineering Research In...
# 27   National Environmental Engineering Research In...
# 100  National Environmental Engineering Research In...
# 28   National Environmental Engineering Research In...
# 101  National Environmental Engineering Research In...
# 147  National Environmental Engineering Research In...
#
#                        Type of Location  SO2  NO2  RSPM/PM10  SPM DateMonth
# 200                     Industrial Area    8   77        289  NaN   2012-01
# 8    Residential, Rural and other Areas    8   82        162  NaN   2012-01
# 201                     Industrial Area   17   96        454  NaN   2012-02
# 209                     Industrial Area   49   81        244  NaN   2012-02
# 96   Residential, Rural and other Areas   15  115        425  NaN   2012-03
# 10   Residential, Rural and other Areas    7   91        183  NaN   2012-03
# 97   Residential, Rural and other Areas   21  112        415  NaN   2012-04
# 217                     Industrial Area    2   76        240  NaN   2012-04
# 218                     Industrial Area    4   99        224  NaN   2012-05
# 26   Residential, Rural and other Areas    3   96        109  NaN   2012-05
# 50   Residential, Rural and other Areas    2   43         55  NaN   2012-06
# 162  Residential, Rural and other Areas    2   27         85  NaN   2012-06
# 192                     Industrial Area   10   87        193  NaN   2012-07
# 0    Residential, Rural and other Areas    5   54        137  NaN   2012-07
# 193                     Industrial Area   17   83        245  NaN   2012-08
# 1    Residential, Rural and other Areas    2   78        179  NaN   2012-08
# 106  Residential, Rural and other Areas   12   84        222  NaN   2012-09
# 205                     Industrial Area   34   56        257  NaN   2012-09
# 99   Residential, Rural and other Areas   19   95        320  NaN   2012-10
# 27   Residential, Rural and other Areas    3   88        190  NaN   2012-10
# 100  Residential, Rural and other Areas   10   81        427  NaN   2012-11
# 28   Residential, Rural and other Areas    4   79         73  NaN   2012-11
# 101  Residential, Rural and other Areas   12   83        312  NaN   2012-12
# 147  Residential, Rural and other Areas    2   49         69  NaN   2012-12

# %%
month12 = ["2012-" + str(j) for j in range(1, 13)]
pd.to_datetime(month12)
# Out:
# DatetimeIndex(['2012-01-01', '2012-02-01', '2012-03-01', '2012-04-01',
#                '2012-05-01', '2012-06-01', '2012-07-01', '2012-08-01',
#                '2012-09-01', '2012-10-01', '2012-11-01', '2012-12-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
data12["Sampling Date"].apply(lambda t: str(t.year)+'-'+str(t.month))
# Out:
# 200     2012-1
# 8       2012-1
# 208     2012-1
# 112     2012-1
# 224     2012-1
# 272     2012-1
# 176     2012-1
# 2       2012-1
# 194     2012-1
# 3       2012-1
# 195     2012-1
# 196     2012-1
# 4       2012-1
# 197     2012-1
# 198     2012-1
# 199     2012-1
# 102     2012-1
# 5       2012-1
# 103     2012-1
# 6       2012-1
# 7       2012-1
# 201     2012-2
# 209     2012-2
# 9       2012-2
# 113     2012-2
# 225     2012-2
# 128     2012-2
# 40      2012-2
# 56      2012-2
# 152     2012-2
#         ...
# 183    2012-11
# 85     2012-11
# 86     2012-11
# 275    2012-11
# 87     2012-11
# 276    2012-11
# 277    2012-11
# 278    2012-11
# 279    2012-11
# 101    2012-12
# 147    2012-12
# 51     2012-12
# 259    2012-12
# 64     2012-12
# 281    2012-12
# 188    2012-12
# 189    2012-12
# 282    2012-12
# 91     2012-12
# 283    2012-12
# 92     2012-12
# 284    2012-12
# 93     2012-12
# 285    2012-12
# 94     2012-12
# 286    2012-12
# 95     2012-12
# 287    2012-12
# 190    2012-12
# 191    2012-12
# Name: Sampling Date, Length: 288, dtype: object

# %%
plt.plot(data12['Sampling Date'],data12['NO2'])
# Out:
# <img src="data:image/png;base64,..." width="640">
