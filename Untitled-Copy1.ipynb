# %%
import pandas as pd

# %%
dateparse = lambda x: pd.datetime.strptime(x, '%d-%m-%y')

data15 = pd.read_csv("cpcb_dly_aq_delhi-2014.csv", parse_dates=['Sampling Date'], date_parser=dateparse).drop("Location of Monitoring Station", axis=1).sort_values("Sampling Date")

# %%
data15
# Out:
#      Stn Code Sampling Date  State City/Town/Village/Area  \
# 0         531    2014-01-01  Delhi                  Delhi
# 226        55    2014-01-01  Delhi                  Delhi
# 663       146    2014-01-04  Delhi                  Delhi
# 169        59    2014-01-04  Delhi                  Delhi
# 397        58    2014-01-04  Delhi                  Delhi
# 328        57    2014-01-05  Delhi                  Delhi
# 101        60    2014-01-05  Delhi                  Delhi
# 416        58    2014-01-07  Delhi                  Delhi
# 597       144    2014-01-07  Delhi                  Delhi
# 687       146    2014-01-07  Delhi                  Delhi
# 188        59    2014-01-07  Delhi                  Delhi
# 423        58    2014-01-08  Delhi                  Delhi
# 195        59    2014-01-08  Delhi                  Delhi
# 201        59    2014-01-09  Delhi                  Delhi
# 429        58    2014-01-09  Delhi                  Delhi
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
plt.plot(data15['Sampling Date'],data15['NO2'])
# Out:
# <img src="data:image/png;base64,..." width="640">
